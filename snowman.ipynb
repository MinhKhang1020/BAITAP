# %%
import turtle
n = turtle.Turtle()
screen = turtle.Screen()
n.hideturtle()
n.speed(5)
screen.bgcolor('black')
n.color('white')
n.fillcolor('white')
n.begin_fill()
n.circle(100)
n.right(180)
n.circle(200)
n.end_fill()
n.left(85)
n.fillcolor('black')
n.penup()
n.forward(60)
n.pendown()
n.begin_fill()
n.circle(5)
n.end_fill()
n.penup()
n.forward(60)
n.pendown()
n.begin_fill()
n.circle(10)
n.end_fill()
n.penup()
n.forward(60)
n.pendown()
n.begin_fill()
n.circle(15)
n.end_fill()
n.penup()
n.forward(70)
n.pendown()
n.begin_fill()
n.circle(20)
n.end_fill()
n.right(140)
n.penup()
n.forward(225)
n.pendown()
n.pensize(10)
n.pencolor('brown')
n.forward(100)
n.right(45)
n.forward(30)
n.backward(30)
n.left(40)
n.forward(30)
n.backward(30)
n.left(45)
n.forward(30)
n.backward(30)
n.penup()
n.goto(155, -70)
n.pendown()
n.right(180)
n.forward(135)
n.backward(30)
n.left(45)
n.forward(30)
n.backward(30)
n.right(40)
n.forward(30)
n.backward(30)
n.right(50)
n.forward(30)
n.backward(30)
n.pencolor('black')
n.penup()
n.pensize(1)
n.goto(-50, 130)
n.pendown()
n.fillcolor('black')
n.begin_fill()
n.circle(5)
n.end_fill()
n.penup()
n.goto(50, 130)
n.pendown()
n.fillcolor('black')
n.begin_fill()
n.circle(5)
n.end_fill()
n.penup()
n.goto(-5, 100)
n.pendown()
n.fillcolor('red')
n.begin_fill()
n.circle(8)
n.end_fill()
n.penup()
n.goto(-50, 50)
n.pendown()
n.pencolor('red')
n.fillcolor('red')
n.begin_fill()
n.circle(60, 130)
n.end_fill()
n.penup()
n.goto(-70, 175)
n.right(70)
n.pendown()
n.fillcolor('yellow')
n.begin_fill()
n.pencolor('black')
n.forward(150)
n.left(140)
n.forward(180)
n.left(100)
n.forward(100)
n.left(160)
n.forward(50)
n.goto(-70, 175)
n.end_fill()
n.left(80)
n.forward(50)
n.fillcolor('white')
n.begin_fill()
n.circle(10)
n.end_fill()


turtle.done()
